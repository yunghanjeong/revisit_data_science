# %% [markdown]
# # Overview
#
# The purpose of this notebook is to review the dataset at a high level and prepare the data for modeling

# %% [markdown]
# ## Libraries Import

# %%
import pandas as pd # pandas for DataFrame data structure 
import numpy as np # numpy for calculation, especially vectorization if necessary
import os # importing OS might be necessary to read files depending on your setup

# %% [markdown]
# ## Data Overview
#
# Pandas is an excellent library for processing any tabulated or similar data. It offers phenomenal out of the box functionality for data structure, analysis, visualization, and many more. It is based on numpy making the data processing extremely fast, at least in terms of python, and has become an industry standard in data science. Many libraries that will be used in this notebook and other tutorials in this series also support pandas streamlining many tasks to come.

# %%
df = pd.read_csv('..\data\Emissions_Canada.csv') # import the csv file as DataFrame
df.head() # print the head (top 5 rows) to preview the data
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244

# %% [markdown]
# ***
# ### Data Cleaning
#
# The first step to any EDA should be checking the completeness of the dataset. If any missing data or obvious outliers are found we can strategize on how to replace or even remove parts of the dataset.

# %%
df.isnull().sum() # chaining isnull with sum methods will provide the total count of missing or null data points on each column
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %% [markdown]
# Looks like the dataset we are dealing with is very clean thanks to Mr. Debajyoti Podder!

# %% [markdown]
# ### Organizing the Columns
#
# Keeping a consistent, clean, and concise naming scheme of the DataFrame columns is a very important aspect that is often overlooked. First, the columns should be clear in delivering the summary of the data that it contains. Second, the columns should be named in a single line of string, connected with underscores if necessary, to take advantage of using the column name as the attribute of the DataFrame. See the example below for my 2nd point.

# %%
df.columns # prints all column names
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.Make # this should print Makes of each index (rows)
# Out:
# 0       ACURA
# 1       ACURA
# 2       ACURA
# 3       ACURA
# 4       ACURA
#         ...
# 7380    VOLVO
# 7381    VOLVO
# 7382    VOLVO
# 7383    VOLVO
# 7384    VOLVO
# Name: Make, Length: 7385, dtype: object

# %%
df.Make.unique() # this should print an array of unique brand names
# Out:
# array(['ACURA', 'ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW',
#        'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE', 'FIAT',
#        'FORD', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP',
#        'KIA', 'LAMBORGHINI', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MASERATI',
#        'MAZDA', 'MERCEDES-BENZ', 'MINI', 'MITSUBISHI', 'NISSAN',
#        'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION', 'SMART', 'SRT', 'SUBARU',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GENESIS', 'BUGATTI'],
#       dtype=object)

# %% [markdown]
# As you might have guessed, the two operations above is not possible with some of the columns, but there are workarounds.

# %%
df.Fuel Type # this will throw a syntax error due to the blank space
# Out:
#   File "<ipython-input-7-c7e3e226111c>", line 1
#     df.Fuel Type # this will throw a syntax error due to the blank space
#                ^
# SyntaxError: invalid syntax

# %%
df['Fuel Type'] # a work around is possible by slicing the DataFrame with the column name as a string
# Out:
# 0       Z
# 1       Z
# 2       Z
# 3       Z
# 4       Z
#        ..
# 7380    Z
# 7381    Z
# 7382    Z
# 7383    Z
# 7384    Z
# Name: Fuel Type, Length: 7385, dtype: object

# %% [markdown]
# Taking some time now to rename these columns will save a lot more time down the line. Also, in this data set there are duplicate columns for combined fuel consumptions where one is provided in L/100km and the other in mpg. I'm going to drop the mpg column to reduce the dataset size and keep the trend of metric units within the dataset.

# %%
# dropping the mpg column

df.drop(labels='Fuel Consumption Comb (mpg)', axis=1, inplace=True)
df.head() # no more mpg columns
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    CO2 Emissions(g/km)
# 0                  196
# 1                  221
# 2                  136
# 3                  255
# 4                  244

# %%
# rename the columns
# use lowercase letters only
# drop any references to units
# connect words with underscores or simplify to a single word
# making new variable for column_names will be cleaner

column_names = ['make', 'model', 'class', 'engine_size', 'cylinders',
       'transmission', 'fuel_type', 'fuel_consumption_city',
       'fuel_consumption_hwy', 'fuel_consumption_comb', 'emissions']

df.columns = column_names
df.head() #columns should be changed
# Out:
#     make       model        class  engine_size  cylinders transmission  \
# 0  ACURA         ILX      COMPACT          2.0          4          AS5
# 1  ACURA         ILX      COMPACT          2.4          4           M6
# 2  ACURA  ILX HYBRID      COMPACT          1.5          4          AV7
# 3  ACURA     MDX 4WD  SUV - SMALL          3.5          6          AS6
# 4  ACURA     RDX AWD  SUV - SMALL          3.5          6          AS6
#
#   fuel_type  fuel_consumption_city  fuel_consumption_hwy  \
# 0         Z                    9.9                   6.7
# 1         Z                   11.2                   7.7
# 2         Z                    6.0                   5.8
# 3         Z                   12.7                   9.1
# 4         Z                   12.1                   8.7
#
#    fuel_consumption_comb  emissions
# 0                    8.5        196
# 1                    9.6        221
# 2                    5.9        136
# 3                   11.1        255
# 4                   10.6        244

# %%
df.fuel_type # now this should print with no error!
# Out:
# 0       Z
# 1       Z
# 2       Z
# 3       Z
# 4       Z
#        ..
# 7380    Z
# 7381    Z
# 7382    Z
# 7383    Z
# 7384    Z
# Name: fuel_type, Length: 7385, dtype: object

# %% [markdown]
# ***
#
# ### Details on Model, Transmission, and Fuel Type Columns
#
# As provided on the [kaggle](https://www.kaggle.com/debajyotipodder/co2-emission-by-vehicles) values within these columns belows can be broken down to the following:
#
# #### Model
#
# - 4WD/4X4 = Four-wheel drive
# - AWD = All-wheel drive
# - FFV = Flexible-fuel vehicle
# - SWB = Short wheelbase
# - LWB = Long wheelbase
# - EWB = Extended wheelbase
#
# #### Transmission
# ***PREFIX***
# - A = Automatic
# - AM = Automated manual
# - AS = Automatic with select shift
# - AV = Continuously variable
# - M = Manual
# ***NUMERICAL SUFFIX***
# - 3 - 10 = Number of gears
#
# #### Fuel Type
# - X = Regular gasoline
# - Z = Premium gasoline
# - D = Diesel
# - E = Ethanol (E85)
# - N = Natural gas
#
# Let's dive deeper into each of these columns and see if we can formulate methods to clean or recategorize some of them. We will work backwards from the list above due to the high variety we will face in transmission and model.

# %%
# Fuel Type data integrity check

df.fuel_type.unique() # looks like there are no incorrect entry on this column
# Out:
# array(['Z', 'D', 'X', 'E', 'N'], dtype=object)

# %% [markdown]
# #### Transmission
# Continous variable Transmission (CVT) are marked as AV**n** (**n** denoting the # gears) in this data set. However, as far as my understanding of CVT design goes, there are no "gears" in the transmission ([wikipedia](https://en.wikipedia.org/wiki/Continuously_variable_transmission) for reference). CVT is designed to continuously change the gear ratio depending on the engine output to provide a linear power output, hence the name. Although, there are certain settings to make CVT feel more like a traditional geared transmission or usage of clutch to quickly change the ratio it's hard to say what the number of gears should be in a given CVT.
#
# Perhaps, the numbers were used to denote the final gearing ratio of the CVT. Meaning that higher the number, more efficient the vehicle is at higher speed, but I cannot be certain of this information. Therefore, I will be changing all entries of AV**n** as CVT.

# %%
# Transmission

df.transmission.unique() #again the entry seems correct, but I see some issues
# Out:
# array(['AS5', 'M6', 'AV7', 'AS6', 'AM6', 'A6', 'AM7', 'AV8', 'AS8', 'A7',
#        'A8', 'M7', 'A4', 'M5', 'AV', 'A5', 'AS7', 'A9', 'AS9', 'AV6',
#        'AS4', 'AM5', 'AM8', 'AM9', 'AS10', 'A10', 'AV10'], dtype=object)

# %%
# this function will convert any entry containing 'AV' as 'CVT'
def transmission_clean(transmission):
    if 'AV' in transmission:
        return 'CVT'
    else:
        return transmission

# %%
df.transmission = df.transmission.apply(transmission_clean) # you can apply a function to the column with this syntax
df.transmission.unique() #now all AV entries should be changed to CVT
# Out:
# array(['AS5', 'M6', 'CVT', 'AS6', 'AM6', 'A6', 'AM7', 'AS8', 'A7', 'A8',
#        'M7', 'A4', 'M5', 'A5', 'AS7', 'A9', 'AS9', 'AS4', 'AM5', 'AM8',
#        'AM9', 'AS10', 'A10'], dtype=object)

# %% [markdown]
# #### Models
#
# Some finesse is going to be required to parse the vehicle model column. Many companies offer many trim levels in a single vehicle model. Also given the repeated model entry it is likely that this dataset contains many vehicles from different year. I will demonstrate this with a simple **groupby** method.

# %%
df.groupby(['make', 'model', 'engine_size', 'transmission'])['class'].count() 
#you can see the multiple entries!
# Out:
# make   model        engine_size  transmission
# ACURA  ILX          2.0          AS5             2
#                     2.4          AM8             5
#                                  M6              2
#        ILX HYBRID   1.5          CVT             2
#        MDX 4WD      3.5          AS6             1
#                                                 ..
# VOLVO  XC70 T6 AWD  3.0          AS6             1
#        XC90 AWD     3.2          AS6             1
#        XC90 T5      2.0          AS8             2
#        XC90 T5 AWD  2.0          AS8             5
#        XC90 T6 AWD  2.0          AS8             5
# Name: class, Length: 3400, dtype: int64

# %% [markdown]
# Let's see what we are dealing with here. Running the code below shows that the model names are quite messy.
# - There are trim level and modification that is listed with model names.
# - Not all AWD or 4x4 systems are named AWD, but uses brand name technology like xDrive.

# %%
for name in df.model:
    if len(name.split()) >= 3:
        print(name)
# Out:
# V8 VANTAGE S
# V8 VANTAGE S
# A5 CABRIOLET QUATTRO
# A6 QUATTRO TDI (modified)
# A7 QUATTRO TDI (modified)
# A8 TDI (modified)
# A8L TDI (modified)
# Q5 TDI (modified)
# Q7 TDI (modified)
# RS 5 CABRIOLET
# TT COUPE QUATTRO
# TT ROADSTER QUATTRO
# TTS COUPE QUATTRO
# TTS ROADSTER QUATTRO
# CONTINENTAL GT SPEED CONVERTIBLE
# 328d xDRIVE TOURING
# 328i xDRIVE GRAN TURISMO
# 328i xDRIVE TOURING
# 335i xDRIVE GRAN TURISMO
# 428i xDRIVE COUPE
# 435i xDRIVE COUPE
# 435i xDRIVE COUPE
# 535i xDRIVE GRAN TURISMO
# 550i xDRIVE GRAN TURISMO
# 640i xDRIVE GRAN COUPE
# 650i xDRIVE CABRIOLET
# 650i xDRIVE COUPE
# 650i xDRIVE GRAN COUPE
# ALPINA B7 xDRIVE LWB
# ALPINA B7 xDRIVE SWB
# M6 GRAN COUPE
# M6 GRAN COUPE
# CTS COUPE AWD
# CTS SEDAN AWD
# CTS SEDAN AWD
# CTS SEDAN Vsport
# CTS SPORT WAGON
# CTS SPORT WAGON
# CTS SPORT WAGON AWD
# CTS SPORT WAGON AWD
# CTS-V SPORT WAGON
# CTS-V SPORT WAGON
# ESCALADE ESV AWD
# ESCALADE ESV AWD
# XTS Vsport AWD
# EXPRESS 1500 CARGO
# EXPRESS 1500 CARGO
# EXPRESS 1500 CARGO
# EXPRESS 1500 CARGO AWD
# EXPRESS 1500 CARGO AWD
# EXPRESS 1500 CARGO CONV
# EXPRESS 1500 CARGO CONV
# EXPRESS 1500 CARGO CONV AWD
# EXPRESS 1500 CARGO CONV AWD
# EXPRESS 1500 PASSENGER
# EXPRESS 1500 PASSENGER
# EXPRESS 1500 PASSENGER AWD
# EXPRESS 1500 PASSENGER AWD
# EXPRESS 2500 PASSENGER
# EXPRESS 2500 PASSENGER
# EXPRESS 2500 PASSENGER
# EXPRESS 3500 PASSENGER
# EXPRESS 3500 PASSENGER
# EXPRESS 3500 PASSENGER
# SONIC 5 RS
# SONIC 5 RS
# 200 CONVERTIBLE FFV
# 200 CONVERTIBLE FFV
# 200 SEDAN FFV
# 200 SEDAN FFV
# 300 AWD (MDS)
# 300 AWD FFV
# 300 AWD FFV
# 300 SRT (MDS)
# TOWN & COUNTRY FFV
# TOWN & COUNTRY FFV
# CHALLENGER SRT (MDS)
# CHARGER AWD (MDS)
# CHARGER AWD FFV
# CHARGER AWD FFV
# CHARGER SRT (MDS)
# DART TURBO AERO
# DART TURBO AERO
# DURANGO AWD (MDS)
# DURANGO AWD FFV
# DURANGO AWD FFV
# GRAND CARAVAN FFV
# GRAND CARAVAN FFV
# 500 ABARTH CABRIO
# 500 ABARTH HATCHBACK
# 500 CABRIO TURBO
# 500 HATCHBACK TURBO
# E150 VAN FFV
# E150 VAN FFV
# E150 VAN FFV
# E150 VAN FFV
# E150 WAGON FFV
# E150 WAGON FFV
# E350 WAGON FFV
# E350 WAGON FFV
# EXPEDITION 4X4 FFV
# EXPEDITION 4X4 FFV
# EXPLORER FFV AWD
# EXPLORER FFV AWD
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 RAPTOR 4X4
# FLEX AWD (EcoBoost)
# FOCUS SFE FFV
# FOCUS SFE FFV
# TAURUS FFV AWD
# TAURUS FFV AWD
# TRANSIT CONNECT TAXI
# TRANSIT CONNECT WAGON
# SAVANA 1500 CARGO
# SAVANA 1500 CARGO
# SAVANA 1500 CARGO
# SAVANA 1500 CARGO AWD
# SAVANA 1500 CARGO AWD
# SAVANA 1500 CARGO CONV
# SAVANA 1500 CARGO CONV
# SAVANA 1500 CARGO CONV AWD
# SAVANA 1500 CARGO CONV AWD
# SAVANA 1500 PASSENGER
# SAVANA 1500 PASSENGER
# SAVANA 1500 PASSENGER AWD
# SAVANA 1500 PASSENGER AWD
# SAVANA 2500 PASSENGER
# SAVANA 2500 PASSENGER
# SAVANA 2500 PASSENGER
# SAVANA 3500 PASSENGER
# SAVANA 3500 PASSENGER
# SAVANA 3500 PASSENGER
# YUKON DENALI AWD
# YUKON DENALI AWD
# YUKON DENALI XL AWD
# YUKON DENALI XL AWD
# YUKON XL 4WD
# YUKON XL 4WD
# SANTA FE 4WD
# SANTA FE SPORT
# SANTA FE SPORT 4WD
# SANTA FE SPORT 4WD
# SONATA HYBRID LIMITED
# Q50 HYBRID AWD
# Q60 AWD COUPE
# QX60 HYBRID AWD
# F-TYPE S CONVERTIBLE
# F-TYPE V8 S CONVERTIBLE
# XF 3.0L AWD
# XJL AWD PORTFOLIO
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE TRAILHAWK 4X4
# CHEROKEE TRAILHAWK 4X4
# COMPASS 4X4 TRAIL RATED
# GRAND CHEROKEE 4X4 (MDS)
# GRAND CHEROKEE 4X4 DIESEL
# GRAND CHEROKEE 4X4 FFV
# GRAND CHEROKEE 4X4 FFV
# GRAND CHEROKEE SRT 4X4 (MDS)
# PATRIOT 4X4 TRAIL RATED
# WRANGLER 4X4 (2-DOOR)
# WRANGLER 4X4 (2-DOOR)
# WRANGLER UNLIMITED 4X4 (4-DOOR)
# WRANGLER UNLIMITED 4X4 (4-DOOR)
# OPTIMA HYBRID EX
# SOUL ECO Dynamics
# RANGE ROVER EVOQUE
# RANGE ROVER EVOQUE COUPE
# RANGE ROVER LWB V8 5.0 SC
# RANGE ROVER LWB V8 5.0 SC FFV
# RANGE ROVER LWB V8 5.0 SC FFV
# RANGE ROVER SPORT V6 3.0 SC
# RANGE ROVER SPORT V6 3.0 SC FFV
# RANGE ROVER SPORT V6 3.0 SC FFV
# RANGE ROVER SPORT V8 5.0 SC
# RANGE ROVER SPORT V8 5.0 SC FFV
# RANGE ROVER SPORT V8 5.0 SC FFV
# RANGE ROVER V6 3.0 SC
# RANGE ROVER V6 3.0 SC FFV
# RANGE ROVER V6 3.0 SC FFV
# RANGE ROVER V8 5.0 SC
# RANGE ROVER V8 5.0 SC FFV
# RANGE ROVER V8 5.0 SC FFV
# GS 350 AWD
# IS 250 AWD
# IS 250 C
# IS 350 AWD
# IS 350 C
# LS 460 AWD
# LS 460 L AWD
# LS 600h L
# RX 350 AWD
# RX 350 AWD
# RX 450h AWD
# MKT LIVERY AWD
# NAVIGATOR 4X4 FFV
# NAVIGATOR 4X4 FFV
# MAZDA3 4-DOOR (i-ELOOP)
# MAZDA3 4-DOOR (SIL)
# MAZDA3 5-DOOR (i-ELOOP)
# MAZDA3 5-DOOR (SIL)
# C 250 COUPE
# C 300 4MATIC FFV
# C 300 4MATIC FFV
# C 350 4MATIC
# C 350 4MATIC COUPE
# C 350 COUPE
# C 63 AMG
# C 63 AMG COUPE
# CL 550 4MATIC
# CL 63 AMG
# CLA 45 AMG 4MATIC
# CLS 550 4MATIC
# CLS 63 AMG 4MATIC
# CLS 63 AMG S 4MATIC
# E 250 BLUETEC 4MATIC
# E 300 4MATIC
# E 350 4MATIC
# E 350 4MATIC COUPE
# E 350 4MATIC WAGON
# E 350 CABRIOLET
# E 350 COUPE
# E 400 HYBRID
# E 550 4MATIC
# E 550 CABRIOLET
# E 550 COUPE
# E 63 AMG 4MATIC
# E 63 AMG 4MATIC WAGON
# E 63 AMG S 4MATIC
# E 63 AMG S 4MATIC WAGON
# G 63 AMG
# GL 350 BLUETEC 4MATIC
# GL 450 4MATIC
# GL 550 4MATIC
# GL 63 AMG
# GLK 250 BLUETEC 4MATIC
# GLK 350 4MATIC
# ML 350 4MATIC FFV
# ML 350 4MATIC FFV
# ML 350 BLUETEC 4MATIC
# ML 550 4MATIC
# ML 63 AMG 4MATIC
# S 550 4MATIC LWB
# S 550 4MATIC SWB
# S 63 AMG 4MATIC
# SL 63 AMG
# SL 65 AMG
# SLK 55 AMG
# SLS AMG BLACK SERIES COUPE
# SLS AMG GT COUPE
# SLS AMG ROADSTER
# COOPER S CLUBMAN
# COOPER S CLUBMAN
# COOPER S CONVERTIBLE
# COOPER S CONVERTIBLE
# COOPER S COUNTRYMAN ALL4
# COOPER S COUNTRYMAN ALL4
# COOPER S COUPE
# COOPER S COUPE
# COOPER S PACEMAN ALL4
# COOPER S PACEMAN ALL4
# COOPER S ROADSTER
# COOPER S ROADSTER
# JOHN COOPER WORKS CLUBMAN
# JOHN COOPER WORKS CLUBMAN
# JOHN COOPER WORKS CONVERTIBLE
# JOHN COOPER WORKS CONVERTIBLE
# JOHN COOPER WORKS COUNTRYMAN ALL4
# JOHN COOPER WORKS COUNTRYMAN ALL4
# JOHN COOPER WORKS COUPE
# JOHN COOPER WORKS COUPE
# JOHN COOPER WORKS PACEMAN ALL4
# JOHN COOPER WORKS PACEMAN ALL4
# JOHN COOPER WORKS ROADSTER
# JOHN COOPER WORKS ROADSTER
# NV200 CARGO VAN
# PATHFINDER HYBRID 4WD
# 911 CARRERA 4
# 911 CARRERA 4
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4S
# 911 CARRERA 4S
# 911 CARRERA 4S CABRIOLET
# 911 CARRERA 4S CABRIOLET
# 911 CARRERA CABRIOLET
# 911 CARRERA CABRIOLET
# 911 CARRERA S
# 911 CARRERA S
# 911 CARRERA S CABRIOLET
# 911 CARRERA S CABRIOLET
# 911 TURBO CABRIOLET
# 911 TURBO S
# 911 TURBO S CABRIOLET
# CAYENNE DIESEL (modified)
# CAYENNE S HYBRID
# CAYENNE TURBO S
# PANAMERA 4S EXECUTIVE
# PANAMERA TURBO EXECUTIVE
# 1500 4X4 (MDS)
# 1500 4X4 (MDS)
# 1500 4X4 DIESEL
# 1500 4X4 FFV
# 1500 4X4 FFV
# CARGO VAN FFV
# CARGO VAN FFV
# PHANTOM DROPHEAD COUPE
# VIPER GTS COUPE
# IMPREZA WAGON AWD
# IMPREZA WAGON AWD
# IMPREZA WAGON AWD
# IMPREZA WAGON AWD
# XV CROSSTREK AWD
# XV CROSSTREK AWD
# XV CROSSTREK HYBRID AWD
# 4RUNNER (Part-Time 4WD)
# CAMRY HYBRID LE
# CAMRY HYBRID XLE/SE
# COROLLA LE ECO (1-mode)
# COROLLA LE ECO (2-mode)
# FJ CRUISER 4WD
# FJ CRUISER 4WD
# HIGHLANDER HYBRID AWD
# HIGHLANDER HYBRID AWD LE
# RAV4 LIMITED AWD
# BEETLE TDI (modified)
# BEETLE TDI (modified)
# GOLF WAGON TDI (modified)
# GOLF WAGON TDI (modified)
# JETTA TDI (modified)
# JETTA TDI (modified)
# JETTA TURBO HYBRID
# PASSAT TDI (modified)
# TOUAREG TDI (modified)
# V8 VANTAGE S
# V8 VANTAGE S
# V12 VANTAGE S
# A3 TDI (modified)
# A3 CABRIOLET QUATTRO
# A4 ALLROAD QUATTRO
# A5 CABRIOLET QUATTRO
# A6 QUATTRO TDI (modified)
# A7 QUATTRO TDI (modified)
# A8 TDI (modified)
# A8L TDI (modified)
# Q5 TDI (modified)
# Q7 TDI (modified)
# RS 5 CABRIOLET
# TT COUPE QUATTRO
# TT ROADSTER QUATTRO
# TTS COUPE QUATTRO
# TTS ROADSTER QUATTRO
# CONTINENTAL GT CONVERTIBLE
# CONTINENTAL GT CONVERTIBLE
# 228i xDRIVE CABRIOLET
# 228i xDRIVE COUPE
# 320i xDRIVE SEDAN
# 328d xDRIVE SEDAN
# 328d xDRIVE TOURING
# 328i xDRIVE SEDAN
# 328i xDRIVE GRAN TURISMO
# 328i xDRIVE TOURING
# 335i xDRIVE SEDAN
# 335i xDRIVE SEDAN
# 335i xDRIVE GRAN TURISMO
# 428i GRAN COUPE
# 428i GRAN COUPE
# 428i xDRIVE CABRIOLET
# 428i xDRIVE COUPE
# 428i xDRIVE GRAN COUPE
# 435i GRAN COUPE
# 435i xDRIVE CABRIOLET
# 435i xDRIVE COUPE
# 435i xDRIVE COUPE
# 435i xDRIVE GRAN COUPE
# 528i xDRIVE SEDAN
# 535d xDRIVE SEDAN
# 535i xDRIVE SEDAN
# 535i xDRIVE GRAN TURISMO
# 550i xDRIVE SEDAN
# 550i xDRIVE GRAN TURISMO
# 640i xDRIVE CABRIOLET
# 640i xDRIVE GRAN COUPE
# 650i xDRIVE CABRIOLET
# 650i xDRIVE COUPE
# 650i xDRIVE GRAN COUPE
# 740Ld xDRIVE SEDAN
# 740Li xDRIVE SEDAN
# 750i xDRIVE SEDAN
# 750Li xDRIVE SEDAN
# ALPINA B6 xDRIVE GRAN COUPE
# ALPINA B7 xDRIVE LWB
# ALPINA B7 xDRIVE SWB
# M235i xDRIVE COUPE
# M6 GRAN COUPE
# M6 GRAN COUPE
# ESCALADE ESV 4WD
# ESCALADE ESV 4WD
# XTS Vsport AWD
# EQUINOX AWD FFV
# EQUINOX AWD FFV
# EXPRESS 2500 PASSENGER
# EXPRESS 2500 PASSENGER
# EXPRESS 2500 PASSENGER FFV
# EXPRESS 2500 PASSENGER FFV
# EXPRESS 3500 PASSENGER
# EXPRESS 3500 PASSENGER
# EXPRESS 3500 PASSENGER FFV
# EXPRESS 3500 PASSENGER FFV
# SONIC 5 RS
# SONIC 5 RS
# 200 AWD FFV
# 200 AWD FFV
# 300 AWD FFV
# 300 AWD FFV
# TOWN & COUNTRY FFV
# TOWN & COUNTRY FFV
# CHALLENGER SRT (MDS)
# CHALLENGER SRT HELLCAT
# CHALLENGER SRT HELLCAT
# CHARGER AWD FFV
# CHARGER AWD FFV
# CHARGER AWD (MDS)
# CHARGER SRT 392 HEMI
# CHARGER SRT HELLCAT
# DART TURBO AERO
# DART TURBO AERO
# DURANGO AWD FFV
# DURANGO AWD FFV
# DURANGO AWD (MDS)
# GRAND CARAVAN FFV
# GRAND CARAVAN FFV
# VIPER SRT COUPE
# 500 HATCHBACK TURBO
# 500 HATCHBACK TURBO
# 500 ABARTH CABRIO
# 500 ABARTH CABRIO
# 500 ABARTH HATCHBACK
# 500 ABARTH HATCHBACK
# EDGE SPORT AWD
# EXPEDITION MAX 4X4
# EXPLORER AWD (EcoBoost)
# EXPLORER FFV AWD
# EXPLORER FFV AWD
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# FLEX AWD (EcoBoost)
# T-150 WAGON FFV
# T-150 WAGON FFV
# TAURUS FFV AWD
# TAURUS FFV AWD
# TRANSIT CONNECT VAN
# TRANSIT CONNECT VAN
# TRANSIT CONNECT WAGON
# TRANSIT CONNECT WAGON TAXI
# SAVANA 2500 PASSENGER
# SAVANA 2500 PASSENGER
# SAVANA 2500 PASSENGER FFV
# SAVANA 2500 PASSENGER FFV
# SAVANA 3500 PASSENGER
# SAVANA 3500 PASSENGER
# SAVANA 3500 PASSENGER FFV
# SAVANA 3500 PASSENGER FFV
# YUKON DENALI 4WD
# YUKON DENALI 4WD
# YUKON XL 4WD
# YUKON XL 4WD
# YUKON XL DENALI 4WD
# YUKON XL DENALI 4WD
# SANTA FE AWD
# SANTA FE SPORT
# SANTA FE SPORT AWD
# SANTA FE SPORT AWD
# SANTA FE ULTIMATE AWD
# SONATA HYBRID LIMITED
# Q50 HYBRID AWD
# QX60 HYBRID AWD
# F-TYPE S CONVERTIBLE
# F-TYPE S COUPE
# F-TYPE V8 R COUPE
# F-TYPE V8 S CONVERTIBLE
# XJL AWD PORTFOLIO
# CHEROKEE 4X4 FFV
# CHEROKEE 4X4 FFV
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE TRAILHAWK 4X4
# CHEROKEE TRAILHAWK 4X4
# COMPASS 4X4 TRAIL RATED
# GRAND CHEROKEE 4X4 DIESEL
# GRAND CHEROKEE 4X4 FFV
# GRAND CHEROKEE 4X4 FFV
# GRAND CHEROKEE 4X4 (MDS)
# GRAND CHEROKEE SRT 4X4 (MDS)
# PATRIOT 4X4 TRAIL RATED
# WRANGLER UNLIMITED 4X4
# WRANGLER UNLIMITED 4X4
# OPTIMA HYBRID EX
# SOUL ECO Dynamics
# RANGE ROVER SUPERCHARGED
# RANGE ROVER SUPERCHARGED
# RANGE ROVER SUPERCHARGED LWB
# RANGE ROVER SUPERCHARGED LWB
# RANGE ROVER EVOQUE
# RANGE ROVER EVOQUE COUPE
# RANGE ROVER SPORT
# RANGE ROVER SPORT SUPERCHARGED
# RANGE ROVER SPORT SUPERCHARGED
# GS 350 AWD
# IS 250 AWD
# IS 250 C
# IS 350 AWD
# IS 350 C
# LS 460 AWD
# LS 460 L AWD
# LS 600h L
# NX 200t AWD
# NX 200t AWD F SPORT
# NX 300h AWD
# RC 350 AWD
# RX 350 AWD
# RX 350 AWD
# RX 450h AWD
# MKT LIVERY AWD
# NAVIGATOR L 4X4
# MAZDA3 4-DOOR (SIL)
# MAZDA3 4-DOOR (i-ELOOP)
# MAZDA3 4-DOOR (SIL)
# MAZDA3 5-DOOR (SIL)
# MAZDA3 5-DOOR (i-ELOOP)
# MAZDA3 5-DOOR (SIL)
# B 250 4MATIC
# C 250 COUPE
# C 300 4MATIC
# C 350 4MATIC COUPE
# C 350 COUPE
# C 400 4MATIC
# C 63 AMG COUPE
# CLA 250 4MATIC
# CLA 45 AMG
# CLS 400 4MATIC
# CLS 550 4MATIC
# CLS 63 AMG 4MATIC
# E 250 BLUETEC 4MATIC
# E 300 4MATIC
# E 400 4MATIC
# E 400 4MATIC WAGON
# E 400 CABRIOLET
# E 400 COUPE
# E 550 4MATIC
# E 550 CABRIOLET
# E 550 COUPE
# E 63 AMG S 4MATIC
# E 63 AMG S 4MATIC WAGON
# G 63 AMG
# GL 350 BLUETEC 4MATIC
# GL 450 4MATIC
# GL 550 4MATIC
# GL 63 AMG
# GLA 250 4MATIC
# GLA 45 AMG 4MATIC
# GLK 250 BLUETEC 4MATIC
# GLK 350 4MATIC
# ML 350 BLUETEC 4MATIC
# ML 400 4MATIC
# ML 550 4MATIC
# ML 63 AMG 4MATIC
# S 400 4MATIC
# S 550 4MATIC COUPE
# S 550 4MATIC LWB
# S 550 4MATIC SWB
# S 63 AMG 4MATIC
# S 63 AMG COUPE
# S 65 AMG
# S 65 AMG COUPE
# SL 63 AMG
# SL 65 AMG
# SLK 55 AMG
# SLS AMG GT COUPE
# SLS AMG GT ROADSTER
# COOPER 3 DOOR
# COOPER 3 DOOR
# COOPER 5 DOOR
# COOPER 5 DOOR
# COOPER S 3 DOOR
# COOPER S 3 DOOR
# COOPER S 5 DOOR
# COOPER S 5 DOOR
# COOPER S CONVERTIBLE
# COOPER S CONVERTIBLE
# COOPER S COUNTRYMAN ALL4
# COOPER S COUNTRYMAN ALL4
# COOPER S COUPE
# COOPER S COUPE
# COOPER S PACEMAN ALL4
# COOPER S PACEMAN ALL4
# COOPER S ROADSTER
# COOPER S ROADSTER
# JOHN COOPER WORKS
# JOHN COOPER WORKS
# JOHN COOPER WORKS CONVERTIBLE
# JOHN COOPER WORKS CONVERTIBLE
# JOHN COOPER WORKS COUNTRYMAN ALL4
# JOHN COOPER WORKS COUNTRYMAN ALL4
# JOHN COOPER WORKS COUPE
# JOHN COOPER WORKS COUPE
# JOHN COOPER WORKS PACEMAN ALL4
# JOHN COOPER WORKS PACEMAN ALL4
# JOHN COOPER WORKS ROADSTER
# JOHN COOPER WORKS ROADSTER
# JUKE NISMO RS
# JUKE NISMO RS AWD
# NV200 CARGO VAN
# PATHFINDER 4WD PLATINUM
# PATHFINDER HYBRID 4WD
# 911 CARRERA CABRIOLET
# 911 CARRERA CABRIOLET
# 911 CARRERA 4
# 911 CARRERA 4
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4 GTS
# 911 CARRERA 4 GTS
# 911 CARRERA 4 GTS CABRIOLET
# 911 CARRERA 4 GTS CABRIOLET
# 911 CARRERA 4S
# 911 CARRERA 4S
# 911 CARRERA 4S CABRIOLET
# 911 CARRERA 4S CABRIOLET
# 911 CARRERA GTS
# 911 CARRERA GTS
# 911 CARRERA GTS CABRIOLET
# 911 CARRERA GTS CABRIOLET
# 911 CARRERA S
# 911 CARRERA S
# 911 CARRERA S CABRIOLET
# 911 CARRERA S CABRIOLET
# 911 TARGA 4
# 911 TARGA 4
# 911 TARGA 4S
# 911 TARGA 4S
# 911 TURBO CABRIOLET
# 911 TURBO S
# 911 TURBO S CABRIOLET
# CAYENNE DIESEL (modified)
# PANAMERA 4S EXECUTIVE
# PANAMERA TURBO EXECUTIVE
# PANAMERA TURBO S
# PANAMERA TURBO S EXECUTIVE
# 1500 ECODIESEL HFE
# 1500 4X4 FFV
# 1500 4X4 FFV
# 1500 4X4 (MDS)
# 1500 4X4 (MDS)
# 1500 4X4 ECODIESEL
# CARGO VAN FFV
# CARGO VAN FFV
# PHANTOM DROPHEAD COUPE
# IMPREZA WAGON AWD
# IMPREZA WAGON AWD
# XV CROSSTREK AWD
# XV CROSSTREK AWD
# XV CROSSTREK HYBRID AWD
# 4RUNNER 4WD (Part-Time 4WD)
# CAMRY HYBRID LE
# CAMRY HYBRID XLE/SE
# COROLLA LE ECO (1-mode)
# COROLLA LE ECO (2-mode)
# HIGHLANDER HYBRID AWD
# HIGHLANDER HYBRID AWD LE
# RAV4 LIMITED AWD
# BEETLE TDI (modified)
# BEETLE TDI (modified)
# GOLF TDI (modified)
# GOLF TDI (modified)
# GOLF SPORTWAGON TDI (modified)
# GOLF SPORTWAGON TDI (modified)
# JETTA TDI (modified)
# JETTA TDI (modified)
# PASSAT TDI (modified)
# PASSAT TDI (modified)
# TOUAREG TDI (modified)
# S60 POLESTAR AWD
# S60 T5 AWD
# S60 T6 AWD
# S80 T6 AWD
# V60 CC AWD
# V60 POLESTAR AWD
# V60 T5 AWD
# V60 T6 AWD
# XC60 3.2 AWD
# XC60 T5 AWD
# XC60 T6 AWD
# XC70 3.2 AWD
# XC70 T6 AWD
# MDX SH-AWD ELITE
# V8 VANTAGE S
# V8 VANTAGE S
# V12 VANTAGE S
# A3 CABRIOLET QUATTRO
# A4 ALLROAD QUATTRO
# A5 CABRIOLET QUATTRO
# A6 QUATTRO TDI (modified)
# A7 QUATTRO TDI (modified)
# A8 QUATTRO TDI (modified)
# Q5 QUATTRO TDI (modified)
# Q5 HYBRID QUATTRO
# RS 7 QUATTRO
# S5 CABRIOLET QUATTRO
# TT COUPE QUATTRO
# TT ROADSTER QUATTRO
# TTS COUPE QUATTRO
# CONTINENTAL GT CONVERTIBLE
# CONTINENTAL GT CONVERTIBLE
# 228i xDRIVE CABRIOLET
# 328d xDRIVE TOURING
# 328i xDRIVE GRAN TURISMO
# 328i xDRIVE TOURING
# 335i xDRIVE GRAN TURISMO
# 428i GRAN COUPE
# 428i GRAN COUPE
# 428i xDRIVE CABRIOLET
# 428i xDRIVE COUPE
# 428i xDRIVE GRAN COUPE
# 435i xDRIVE CABRIOLET
# 435i xDRIVE COUPE
# 435i xDRIVE COUPE
# 435i xDRIVE GRAN COUPE
# 535i xDRIVE GRAN TURISMO
# 550i xDRIVE GRAN TURISMO
# 640i xDRIVE CABRIOLET
# 640i xDRIVE GRAN COUPE
# 650i xDRIVE CABRIOLET
# 650i xDRIVE COUPE
# 650i xDRIVE GRAN COUPE
# ALPINA B6 xDRIVE GRAN COUPE
# M235i xDRIVE CABRIOLET
# M6 GRAN COUPE
# M6 GRAN COUPE
# ENCORE SPORT TOURING
# ENCORE SPORT TOURING AWD
# LACROSSE AWD FFV
# LACROSSE AWD FFV
# XTS Vsport AWD
# CRUZE LIMITED ECO
# CRUZE LIMITED ECO
# EQUINOX AWD FFV
# EQUINOX AWD FFV
# EXPRESS 2500 PASSENGER
# EXPRESS 3500 PASSENGER
# IMPALA DUAL FUEL
# IMPALA DUAL FUEL
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO eASSIST 4WD
# SONIC 5 RS
# SONIC 5 RS
# SUBURBAN 4WD FFV
# SUBURBAN 4WD FFV
# TAHOE 4WD FFV
# TAHOE 4WD FFV
# 200 AWD FFV
# 200 AWD FFV
# 300 AWD FFV
# 300 AWD FFV
# TOWN & COUNTRY FFV
# TOWN & COUNTRY FFV
# CHALLENGER SRT (MDS)
# CHALLENGER SRT HELLCAT
# CHALLENGER SRT HELLCAT
# CHARGER AWD FFV
# CHARGER AWD FFV
# CHARGER AWD (MDS)
# CHARGER SRT (MDS)
# CHARGER SRT HELLCAT
# DART TURBO AERO
# DART TURBO AERO
# DURANGO AWD (MDS)
# GRAND CARAVAN FFV
# GRAND CARAVAN FFV
# 500 HATCHBACK TURBO
# 500 HATCHBACK TURBO
# 500 ABARTH CABRIO
# 500 ABARTH CABRIO
# 500 ABARTH HATCHBACK
# 500 ABARTH HATCHBACK
# EXPEDITION EL 4X4
# EXPLORER FFV AWD
# EXPLORER FFV AWD
# F-150 (Payload Pkg)
# F-150 (Payload Pkg)
# F-150 FFV (Payload Pkg)
# F-150 FFV (Payload Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4 (Payload Pkg)
# F-150 FFV 4X4 (Payload Pkg)
# FLEX AWD GTDI
# FOCUS RS AWD
# SHELBY GT350 MUSTANG
# T-150 WAGON FFV
# T-150 WAGON FFV
# TAURUS FFV AWD
# TAURUS FFV AWD
# TRANSIT CONNECT VAN
# TRANSIT CONNECT VAN
# TRANSIT CONNECT VAN FFV
# TRANSIT CONNECT VAN FFV
# TRANSIT CONNECT WAGON
# TRANSIT CONNECT WAGON FFV
# TRANSIT CONNECT WAGON FFV
# TRANSIT CONNECT WAGON LWB
# TRANSIT CONNECT WAGON LWB FFV
# TRANSIT CONNECT WAGON LWB FFV
# SAVANA 2500 PASSENGER
# SAVANA 3500 PASSENGER
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA eASSIST 4WD
# YUKON 4WD FFV
# YUKON 4WD FFV
# YUKON XL FFV
# YUKON XL FFV
# YUKON XL 4WD
# YUKON XL 4WD
# YUKON XL 4WD FFV
# YUKON XL 4WD FFV
# SANTA FE AWD
# SANTA FE SPORT
# SANTA FE SPORT AWD
# SANTA FE SPORT AWD
# SANTA FE ULTIMATE AWD
# SONATA HYBRID LIMITED
# Q50S RED SPORT
# Q50S RED SPORT AWD
# Q50 HYBRID AWD
# QX60 HYBRID AWD
# F-TYPE PROJECT 7 CONVERTIBLE
# F-TYPE R AWD CONVERTIBLE
# F-TYPE R AWD COUPE
# F-TYPE S CONVERTIBLE
# F-TYPE S CONVERTIBLE
# F-TYPE S CONVERTIBLE AWD
# F-TYPE S COUPE
# F-TYPE S COUPE
# F-TYPE S COUPE AWD
# XJ R-SPORT 3.0 AWD
# XJL 3.0 AWD PORTFOLIO
# CHEROKEE 4X4 FFV
# CHEROKEE 4X4 FFV
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE TRAILHAWK 4X4
# CHEROKEE TRAILHAWK 4X4
# COMPASS 4X4 TRAIL RATED
# GRAND CHEROKEE 4X4
# GRAND CHEROKEE 4X4 (MDS)
# GRAND CHEROKEE 4X4 DIESEL
# GRAND CHEROKEE SRT 4X4 (MDS)
# PATRIOT 4X4 TRAIL RATED
# WRANGLER UNLIMITED 4X4
# WRANGLER UNLIMITED 4X4
# OPTIMA HYBRID EX
# SOUL ECO DYNAMICS
# RANGE ROVER TD6 DIESEL
# RANGE ROVER SUPERCHARGED
# RANGE ROVER SUPERCHARGED LWB
# RANGE ROVER SPORT
# RANGE ROVER SPORT TD6 DIESEL
# RANGE ROVER SPORT SUPERCHARGED
# RANGE ROVER EVOQUE
# GS 200t F SPORT
# GS 350 AWD
# GS 350 F SPORT
# IS 300 AWD
# IS 350 AWD
# LS 460 AWD
# LS 460 L AWD
# LS 600h L
# NX 200t AWD
# NX 200t AWD F SPORT
# NX 300h AWD
# RC 300 AWD
# RC 350 AWD
# RX 350 AWD
# RX 450h AWD
# MKT LIVERY AWD
# NAVIGATOR L 4X4
# MAZDA3 4-DOOR (SIL)
# MAZDA3 4-DOOR (i-ELOOP)
# MAZDA3 4-DOOR (SIL)
# MAZDA3 5-DOOR (SIL)
# MAZDA3 5-DOOR (i-ELOOP)
# MAZDA3 5-DOOR (SIL)
# AMG C 63
# AMG C 63 S
# AMG CLA 45
# AMG CLS 63 S 4MATIC
# AMG E 63 S 4MATIC
# AMG E 63 S 4MATIC WAGON
# AMG G 63
# AMG G 65
# AMG GL 63 S
# AMG GLA 45
# AMG GLE 63 S 4MATIC
# AMG GLE 63 S COUPE 4MATIC
# AMG GT S
# AMG S 63
# AMG S 63 COUPE
# AMG S 65
# AMG S 65 COUPE
# AMG SL 63
# AMG SL 65
# AMG SLK 55
# B 250 4MATIC
# C 300 4MATIC
# C 450 AMG SPORT 4MATIC
# CLA 250 4MATIC FFV
# CLA 250 4MATIC FFV
# CLS 400 4MATIC
# CLS 550 4MATIC
# E 250 BLUETEC 4MATIC
# E 300 4MATIC
# E 400 4MATIC
# E 400 4MATIC COUPE
# E 400 4MATIC WAGON
# E 400 CABRIOLET
# E 550 4MATIC
# E 550 CABRIOLET
# E 550 COUPE
# GL 350 BLUETEC 4MATIC
# GL 450 4MATIC
# GL 550 4MATIC
# GLA 250 4MATIC
# GLE 350d 4MATIC
# GLE 350d 4MATIC COUPE
# GLE 400 4MATIC
# GLE 450 AMG SPORT 4MATIC COUPE
# GLE 550 4MATIC
# MAYBACH S 600
# S 400 4MATIC SWB
# S 550 4MATIC SWB
# S 550 4MATIC LWB
# S 550 4MATIC COUPE
# COOPER 3 DOOR
# COOPER 3 DOOR
# COOPER 5 DOOR
# COOPER 5 DOOR
# COOPER S 3 DOOR
# COOPER S 3 DOOR
# COOPER S 5 DOOR
# COOPER S 5 DOOR
# COOPER S CLUBMAN
# COOPER S CLUBMAN
# COOPER S CONVERTIBLE
# COOPER S CONVERTIBLE
# COOPER S COUNTRYMAN ALL4
# COOPER S COUNTRYMAN ALL4
# COOPER S PACEMAN ALL4
# COOPER S PACEMAN ALL4
# JOHN COOPER WORKS
# JOHN COOPER WORKS
# JOHN COOPER WORKS COUNTRYMAN ALL4
# JOHN COOPER WORKS COUNTRYMAN ALL4
# JOHN COOPER WORKS PACEMAN ALL4
# JOHN COOPER WORKS PACEMAN ALL4
# JUKE NISMO RS
# JUKE NISMO RS AWD
# NV200 CARGO VAN
# PATHFINDER 4WD PLATINUM
# 911 CARRERA CABRIOLET
# 911 CARRERA CABRIOLET
# 911 CARRERA GTS
# 911 CARRERA GTS
# 911 CARRERA GTS CABRIOLET
# 911 CARRERA GTS CABRIOLET
# 911 CARRERA S
# 911 CARRERA S
# 911 CARRERA S CABRIOLET
# 911 CARRERA S CABRIOLET
# 911 CARRERA 4
# 911 CARRERA 4
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4 GTS
# 911 CARRERA 4 GTS
# 911 CARRERA 4 GTS CABRIOLET
# 911 CARRERA 4 GTS CABRIOLET
# 911 CARRERA 4S
# 911 CARRERA 4S
# 911 CARRERA 4S CABRIOLET
# 911 CARRERA 4S CABRIOLET
# 911 TARGA 4
# 911 TARGA 4
# 911 TARGA 4S
# 911 TARGA 4S
# 911 TURBO CABRIOLET
# 911 TURBO S
# 911 TURBO S CABRIOLET
# CAYENNE DIESEL (modified)
# CAYENNE TURBO S
# PANAMERA 4S EXECUTIVE
# PANAMERA TURBO EXECUTIVE
# PANAMERA TURBO S
# PANAMERA TURBO S EXECUTIVE
# 1500 ECODIESEL HFE
# 1500 4X4 FFV
# 1500 4X4 FFV
# 1500 4X4 (MDS)
# 1500 4X4 (MDS)
# 1500 4X4 ECODIESEL
# PHANTOM DROPHEAD COUPE
# IMPREZA WAGON AWD
# IMPREZA WAGON AWD
# XV CROSSTREK AWD
# XV CROSSTREK AWD
# XV CROSSTREK HYBRID AWD
# 4RUNNER 4WD (Part-Time 4WD)
# CAMRY HYBRID LE
# CAMRY HYBRID XLE/SE
# COROLLA LE ECO (1-mode)
# COROLLA LE ECO (2-mode)
# HIGHLANDER HYBRID AWD
# HIGHLANDER HYBRID AWD LE
# RAV4 HYBRID AWD
# RAV4 LIMITED/SE AWD
# TACOMA 4WD D-CAB OFF-ROAD
# TOUAREG TDI (modified)
# S60 CC T5 AWD
# S60 INSCRIPTION T5 AWD
# S60 T5 AWD
# S60 T6 AWD
# S60 3.0T AWD
# V60 CC T5 AWD
# V60 T5 AWD
# V60 T6 AWD
# V60 3.0T AWD
# XC60 T5 AWD
# XC60 T6 AWD
# XC60 3.0T AWD
# XC70 T5 AWD
# XC90 T5 AWD
# XC90 T6 AWD
# MDX SH-AWD ELITE
# MDX HYBRID AWD
# V12 VANTAGE S
# V12 VANTAGE S
# A3 CABRIOLET QUATTRO
# A4 ALLROAD QUATTRO
# A5 CABRIOLET QUATTRO
# TT COUPE QUATTRO
# TT ROADSTER QUATTRO
# TTS COUPE QUATTRO
# CONTINENTAL GT CONVERTIBLE
# CONTINENTAL GT CONVERTIBLE
# 230i xDRIVE CABRIOLET
# 230i xDRIVE COUPE
# 328d xDRIVE TOURING
# 330i xDRIVE GRAN TURISMO
# 330i xDRIVE TOURING
# 340i xDRIVE GRAN TURISMO
# 430i xDRIVE CABRIOLET
# 430i xDRIVE COUPE
# 430i xDRIVE GRAN COUPE
# 440i xDRIVE CABRIOLET
# 440i xDRIVE COUPE
# 440i xDRIVE COUPE
# 440i xDRIVE GRAN COUPE
# 640i xDRIVE CABRIOLET
# 640i xDRIVE GRAN COUPE
# 650i xDRIVE CABRIOLET
# 650i xDRIVE COUPE
# 650i xDRIVE GRAN COUPE
# ALPINA B6 xDRIVE GRAN COUPE
# ALPINA B7 xDRIVE
# M240i xDRIVE CABRIOLET
# M240i xDRIVE COUPE
# M6 GRAN COUPE
# M6 GRAN COUPE
# ENCORE (LUV Engine)
# ENCORE (LE2 Engine)
# ENCORE AWD (LUV Engine)
# ENCORE AWD (LE2 Engine)
# XTS Vsport AWD
# COLORADO ZR2 4WD
# COLORADO ZR2 4WD
# CRUZE HATCHBACK PREMIER
# EQUINOX AWD FFV
# EQUINOX AWD FFV
# EXPRESS 2500 PASSENGER
# EXPRESS 3500 PASSENGER
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO eASSIST 4WD
# SUBURBAN 4WD FFV
# SUBURBAN 4WD FFV
# TAHOE 4WD FFV
# TAHOE 4WD FFV
# 200 AWD FFV
# 200 AWD FFV
# 300 AWD FFV
# 300 AWD FFV
# CHALLENGER SRT (MDS)
# CHALLENGER SRT HELLCAT
# CHALLENGER SRT HELLCAT
# CHARGER AWD FFV
# CHARGER AWD FFV
# CHARGER SRT (MDS)
# CHARGER SRT HELLCAT
# GRAND CARAVAN FFV
# GRAND CARAVAN FFV
# 500 ABARTH CABRIO
# 500 ABARTH CABRIO
# 500 ABARTH HATCHBACK
# 500 ABARTH HATCHBACK
# EXPEDITION EL 4X4
# EXPLORER FFV AWD
# EXPLORER FFV AWD
# F-150 (LT Tire Pkg)
# F-150 (Payload Pkg)
# F-150 (LT Tire Pkg)
# F-150 (Payload Pkg)
# F-150 FFV (Payload Pkg)
# F-150 FFV (Payload Pkg)
# F-150 4X4 (LT Tire Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 4X4 (LT Tire Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (Payload Pkg)
# F-150 FFV 4X4 (Payload Pkg)
# F-150 RAPTOR 4X4
# FLEX AWD GTDI
# FOCUS RS AWD
# MUSTANG (Performance Pkg)
# MUSTANG (Performance Pkg)
# MUSTANG (Performance Pkg)
# SHELBY GT350 MUSTANG
# T-150 WAGON FFV
# T-150 WAGON FFV
# TAURUS FFV AWD
# TAURUS FFV AWD
# TRANSIT CONNECT VAN FFV
# TRANSIT CONNECT VAN FFV
# TRANSIT CONNECT WAGON LWB FFV
# TRANSIT CONNECT WAGON LWB FFV
# SAVANA 2500 PASSENGER
# SAVANA 3500 PASSENGER
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA eASSIST 4WD
# YUKON 4WD FFV
# YUKON 4WD FFV
# YUKON DENALI 4WD
# YUKON XL FFV
# YUKON XL FFV
# YUKON XL 4WD
# YUKON XL 4WD FFV
# YUKON XL 4WD FFV
# YUKON XL DENALI 4WD
# SANTA FE AWD
# SANTA FE SPORT
# SANTA FE SPORT AWD
# SANTA FE SPORT AWD
# SANTA FE ULTIMATE AWD
# SONATA HYBRID SE
# Q50S RED SPORT AWD
# Q50 HYBRID AWD
# Q60S RED SPORT AWD
# QX60 HYBRID AWD
# F-TYPE R CONVERTIBLE AWD
# F-TYPE R COUPE AWD
# F-TYPE S CONVERTIBLE
# F-TYPE S CONVERTIBLE
# F-TYPE S CONVERTIBLE AWD
# F-TYPE S COUPE
# F-TYPE S COUPE
# F-TYPE S COUPE AWD
# XE 20d AWD
# XE 35t AWD
# XF 20d AWD
# XF 35t AWD
# XJ R-SPORT 3.0 AWD
# XJL PORTFOLIO 3.0 AWD
# CHEROKEE 4X4 ACTIVE DRIVE I
# CHEROKEE 4X4 ACTIVE DRIVE I
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE 4X4 ACTIVE DRIVE LOCK
# CHEROKEE 4X4 ACTIVE DRIVE LOCK
# GRAND CHEROKEE 4X4
# GRAND CHEROKEE 4X4
# GRAND CHEROKEE SRT8
# NEW COMPASS 4X4
# NEW COMPASS 4X4
# WRANGLER UNLIMITED 4X4
# WRANGLER UNLIMITED 4X4
# SORENTO AWD FE
# AVENTADOR COUPE LP 740
# AVENTADOR ROADSTER LP 740
# RANGE ROVER EVOQUE
# RANGE ROVER EVOQUE CONVERTIBLE
# GS 350 AWD
# IS 300 AWD
# IS 350 AWD
# LS 460 AWD
# LS 460 L AWD
# NX 200t AWD
# NX 200t AWD F SPORT
# NX 300h AWD
# RC 300 AWD
# RC 350 AWD
# RX 350 AWD
# RX 450h AWD
# MKC AWD (Start/Stop)
# MKT LIVERY AWD
# NAVIGATOR L 4X4
# MAZDA3 4-DOOR (SIL)
# MAZDA3 4-DOOR (i-ELOOP)
# MAZDA3 4-DOOR (SIL)
# MAZDA3 5-DOOR (SIL)
# MAZDA3 5-DOOR (i-ELOOP)
# MAZDA3 5-DOOR (SIL)
# AMG C 63
# AMG C 63 CABRIOLET
# AMG C 63 COUPE
# AMG C 63 S
# AMG C 63 S CABRIOLET
# AMG C 63 S COUPE
# AMG CLA 45
# AMG CLS 63 S 4MATIC
# AMG G 63
# AMG G 65
# AMG GLA 45 4MATIC
# AMG GLC 43 4MATIC COUPE
# AMG GLE 43 4MATIC
# AMG GLE 43 4MATIC COUPE
# AMG GLE 63 S 4MATIC
# AMG GLE 63 S 4MATIC COUPE
# AMG GLS 63
# AMG GT COUPE
# AMG GT S COUPE
# AMG S 63 4MATIC
# AMG S 63 CABRIOLET
# AMG S 63 COUPE
# AMG S 65
# AMG S 65 CABRIOLET
# AMG S 65 COUPE
# AMG SL 63
# AMG SL 65
# AMG SLC 43
# C 300 4MATIC
# C 300 4MATIC CABRIOLET
# C 300 4MATIC COUPE
# CLS 550 4MATIC
# E 300 4MATIC
# E 400 4MATIC
# E 400 4MATIC WAGON
# E 400 CABRIOLET
# E 400 COUPE
# E 550 CABRIOLET
# E 550 COUPE
# GLA 250 4MATIC
# GLA 250 4MATIC
# GLC 300 4MATIC
# GLE 400 4MATIC
# GLE 550 4MATIC
# GLS 450 4MATIC
# GLS 550 4MATIC
# MAYBACH S 600
# S 400 4MATIC SWB
# S 550 4MATIC SWB
# S 550 4MATIC LWB
# S 550 4MATIC CABRIOLET
# S 550 4MATIC COUPE
# COOPER 3 DOOR
# COOPER 3 DOOR
# COOPER 5 DOOR
# COOPER 5 DOOR
# COOPER CLUBMAN ALL4
# COOPER CLUBMAN ALL4
# COOPER COUNTRYMAN ALL4
# COOPER COUNTRYMAN ALL4
# COOPER S 3 DOOR
# COOPER S 3 DOOR
# COOPER S 5 DOOR
# COOPER S 5 DOOR
# COOPER S CLUBMAN
# COOPER S CLUBMAN
# COOPER S CLUBMAN ALL4
# COOPER S CLUBMAN ALL4
# COOPER S CONVERTIBLE
# COOPER S CONVERTIBLE
# COOPER S COUNTRYMAN  ALL4
# COOPER S COUNTRYMAN  ALL4
# JOHN COOPER WORKS 3 DOOR
# JOHN COOPER WORKS 3 DOOR
# JOHN COOPER WORKS CLUBMAN ALL4
# JOHN COOPER WORKS CLUBMAN ALL4
# JOHN COOPER WORKS CONVERTIBLE
# JOHN COOPER WORKS CONVERTIBLE
# JUKE NISMO RS
# JUKE NISMO RS AWD
# NV200 CARGO VAN
# PATHFINDER 4WD PLATINUM
# TITAN 4WD PRO-4X
# 911 CARRERA CABRIOLET
# 911 CARRERA CABRIOLET
# 911 CARRERA S
# 911 CARRERA S
# 911 CARRERA S CABRIOLET
# 911 CARRERA S CABRIOLET
# 911 CARRERA 4
# 911 CARRERA 4
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4S
# 911 CARRERA 4S
# 911 CARRERA 4S CABRIOLET
# 911 CARRERA 4S CABRIOLET
# 911 TARGA 4
# 911 TARGA 4
# 911 TARGA 4S
# 911 TARGA 4S
# 911 TURBO CABRIOLET
# 911 TURBO S
# 911 TURBO S CABRIOLET
# CAYENNE TURBO S
# 1500 4X4 FFV
# 1500 4X4 FFV
# 1500 4X4 ECODIESEL
# PHANTOM DROPHEAD COUPE
# IMPREZA 4-DOOR AWD
# IMPREZA 4-DOOR AWD
# IMPREZA 5-DOOR AWD
# IMPREZA 5-DOOR AWD
# 4RUNNER 4WD (Part-Time 4WD)
# CAMRY HYBRID LE
# CAMRY HYBRID XLE/SE
# COROLLA LE ECO (1-mode)
# COROLLA LE ECO (2-mode)
# HIGHLANDER AWD (Start/Stop System)
# HIGHLANDER AWD LE
# HIGHLANDER HYBRID AWD
# RAV4 LIMITED/SE AWD
# RAV4 HYBRID AWD
# TACOMA 4WD D-CAB OFF-ROAD
# GOLF SPORTWAGEN 4MOTION
# S60 T5 AWD
# S60 INSCRIPTION T5
# S60 INSCRIPTION T5 AWD
# S60 T6 AWD
# S60 CC T5 AWD
# S90 T6 AWD
# V60 T5 AWD
# V60 T6 AWD
# V60 CC T5 AWD
# V90 T6 AWD
# V90 CC T6 AWD
# XC60 T5 AWD
# XC60 T6 AWD
# XC90 T5 AWD
# XC90 T6 AWD
# MDX SH-AWD ELITE
# MDX HYBRID AWD
# TLX SH-AWD A-SPEC
# A3 CABRIOLET QUATTRO
# A4 ALLROAD QUATTRO
# A5 CABRIOLET QUATTRO
# A5 SPORTBACK QUATTRO
# TT COUPE QUATTRO
# TT ROADSTER QUATTRO
# CONTINENTAL GT CONVERTIBLE
# 230i xDRIVE CABRIOLET
# 230i xDRIVE COUPE
# 328d xDRIVE TOURING
# 330i xDRIVE GRAN TURISMO
# 330i xDRIVE TOURING
# 340i xDRIVE GRAN TURISMO
# 430i xDRIVE CABRIOLET
# 430i xDRIVE COUPE
# 430i xDRIVE GRAN COUPE
# 440i xDRIVE CABRIOLET
# 440i xDRIVE COUPE
# 440i xDRIVE COUPE
# 440i xDRIVE GRAN COUPE
# 640i xDRIVE CABRIOLET
# 640i xDRIVE GRAN COUPE
# 640i xDRIVE GRAN TURISMO
# 650i xDRIVE CABRIOLET
# 650i xDRIVE COUPE
# 650i xDRIVE GRAN COUPE
# 750i xDRIVE SWB
# ALPINA B6 xDRIVE GRAN COUPE
# M240i xDRIVE CABRIOLET
# M240i xDRIVE COUPE
# M6 GRAN COUPE
# M6 GRAN COUPE
# ENCORE (SIDI with Stop/Start)
# ENCORE AWD (SIDI with Stop/Start)
# XTS Vsport AWD
# COLORADO ZR2 4WD
# COLORADO ZR2 4WD
# CRUZE HATCHBACK PREMIER
# CRUZE HATCHBACK DIESEL
# CRUZE HATCHBACK DIESEL
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO 4WD FFV
# SILVERADO eASSIST 4WD
# SUBURBAN 4WD FFV
# SUBURBAN 4WD FFV
# TAHOE 4WD FFV
# TAHOE 4WD FFV
# 300 AWD FFV
# 300 AWD FFV
# CHALLENGER GT AWD
# CHALLENGER GT AWD FFV
# CHALLENGER GT AWD FFV
# CHALLENGER SRT (MDS)
# CHALLENGER SRT DEMON
# CHALLENGER SRT HELLCAT
# CHALLENGER SRT HELLCAT
# CHARGER AWD FFV
# CHARGER AWD FFV
# CHARGER AWD (MDS)
# CHARGER SRT (MDS)
# CHARGER SRT HELLCAT
# DURANGO AWD SRT
# GRAND CARAVAN FFV
# GRAND CARAVAN FFV
# EXPEDITION MAX 4X4
# EXPLORER FFV AWD
# EXPLORER FFV AWD
# F-150 (LT Tire Pkg)
# F-150 (Payload Pkg)
# F-150 (LT Tire Pkg)
# F-150 (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 (LT Tire Pkg)
# F-150 (Payload Pkg)
# F-150 (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 (Payload Pkg)
# F-150 FFV (Payload Pkg)
# F-150 FFV (Payload Pkg)
# F-150 4X4 (LT Tire Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 4X4 (LT Tire Pkg)
# F-150 4X4 XL/XLT
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 4X4 (LT Tire Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 FFV 4X4 (Payload Pkg)
# F-150 FFV 4X4 (Payload Pkg)
# F-150 RAPTOR 4WD
# FLEX AWD GTDI
# FOCUS RS AWD
# MUSTANG (Performance Pkg)
# MUSTANG (Performance Pkg)
# SHELBY GT350 MUSTANG
# TAURUS FFV AWD
# TAURUS FFV AWD
# TRANSIT CONNECT VAN FFV
# TRANSIT CONNECT VAN FFV
# TRANSIT CONNECT WAGON LWB FFV
# TRANSIT CONNECT WAGON LWB FFV
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA 4WD FFV
# SIERRA eASSIST 4WD
# YUKON 4WD FFV
# YUKON 4WD FFV
# YUKON XL FFV
# YUKON XL FFV
# YUKON XL 4WD
# YUKON XL 4WD FFV
# YUKON XL 4WD FFV
# YUKON XL 4WD
# CIVIC COUPE Si
# CIVIC HATCHBACK SPORT
# CIVIC HATCHBACK SPORT
# CIVIC SEDAN Si
# CIVIC TYPE R
# SANTA FE AWD
# SANTA FE ULTIMATE AWD
# SANTA FE SPORT
# SANTA FE SPORT AWD
# SANTA FE SPORT ULTIMATE AWD
# SONATA HYBRID SE
# Q50 AWD RED SPORT
# Q50 HYBRID AWD
# Q60 AWD RED SPORT
# F-TYPE CONVERTIBLE R-DYNAMIC
# F-TYPE CONVERTIBLE R-DYNAMIC
# F-TYPE CONVERTIBLE R-DYNAMIC AWD
# F-TYPE COUPE R-DYNAMIC
# F-TYPE COUPE R-DYNAMIC
# F-TYPE COUPE R-DYNAMIC AWD
# F-TYPE R AWD CONVERTIBLE
# F-TYPE R AWD COUPE
# XE 20d AWD
# XE 25t AWD
# XE 35t AWD
# XF 20d AWD
# XF 25t AWD
# XF 35t AWD
# XJ R-SPORT AWD
# XJL PORTFOLIO AWD
# CHEROKEE 4X4 ACTIVE DRIVE I
# CHEROKEE 4X4 ACTIVE DRIVE I FFV
# CHEROKEE 4X4 ACTIVE DRIVE I FFV
# CHEROKEE 4X4 ACTIVE DRIVE I
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE 4X4 ACTIVE DRIVE II
# CHEROKEE 4X4 ACTIVE DRIVE LOCK
# CHEROKEE 4X4 ACTIVE DRIVE LOCK
# GRAND CHEROKEE 4X4
# GRAND CHEROKEE 4X4
# GRAND CHEROKEE 4X4
# GRAND CHEROKEE 4X4 SRT
# GRAND CHEROKEE 4X4 TRACKHAWK
# NEW WRANGLER 4X4
# NEW WRANGLER 4X4
# NEW WRANGLER 4X4
# NEW WRANGLER UNLIMITED 4X4
# NEW WRANGLER UNLIMITED 4X4
# NEW WRANGLER UNLIMITED 4X4
# WRANGLER JK 4X4
# WRANGLER JK 4X4
# WRANGLER JK UNLIMITED 4X4
# WRANGLER JK UNLIMITED 4X4
# SORENTO AWD FE
# AVENTADOR S COUPE
# AVENTADOR S ROADSTER
# HURACAN SPYDER AWD
# RANGE ROVER EVOQUE
# RANGE ROVER EVOQUE CONVERTIBLE
# RANGE ROVER VELAR
# RANGE ROVER VELAR
# GS 350 AWD
# IS 300 AWD
# IS 350 AWD
# LS 500 AWD
# LS 500h AWD
# NX 300 AWD
# NX 300 AWD F SPORT
# NX 300h AWD
# RC 300 AWD
# RC 350 AWD
# RX 350 AWD
# RX 350 L AWD
# RX 450h AWD
# MKC AWD (Start/Stop)
# MKT LIVERY AWD
# CX-5 (Cylinder Deactivation)
# CX-5 4WD (Cylinder Deactivation)
# MAZDA3 4-DOOR (SIL)
# MAZDA3 4-DOOR (i-ELOOP)
# MAZDA3 4-DOOR (SIL)
# MAZDA3 5-DOOR (SIL)
# MAZDA3 5-DOOR (i-ELOOP)
# MAZDA3 5-DOOR (SIL)
# AMG C 43 4MATIC
# AMG C 43 4MATIC CABRIOLET
# AMG C 43 4MATIC COUPE
# AMG C 63
# AMG C 63 CABRIOLET
# AMG C 63 COUPE
# AMG C 63 S
# AMG C 63 S CABRIOLET
# AMG C 63 S COUPE
# AMG CLA 45 4MATIC
# AMG E 43 4MATIC
# AMG E 63 S 4MATIC
# AMG E 63 S 4MATIC WAGON
# AMG G 63
# AMG G 65
# AMG GLA 45 4MATIC
# AMG GLC 43 4MATIC
# AMG GLC 43 4MATIC COUPE
# AMG GLE 43 4MATIC
# AMG GLE 43 4MATIC COUPE
# AMG GLE 63 S 4MATIC
# AMG GLE 63 S 4MATIC COUPE
# AMG GLS 63 4MATIC
# AMG GT COUPE
# AMG GT ROADSTER
# AMG GT C COUPE
# AMG GT C ROADSTER
# AMG GT R COUPE
# AMG GT S COUPE
# AMG S 63 4MATIC
# AMG S 63 4MATIC CABRIOLET
# AMG S 63 4MATIC COUPE
# AMG S 65
# AMG SL 63
# AMG SL 65
# AMG SLC 43
# B 250 4MATIC
# C 300 4MATIC
# C 300 4MATIC CABRIOLET
# C 300 4MATIC COUPE
# C 300 4MATIC WAGON
# CLA 250 4MATIC
# E 300 4MATIC
# E 400 4MATIC
# E 400 4MATIC CABRIOLET
# E 400 4MATIC COUPE
# E 400 4MATIC WAGON
# GLA 250 4MATIC
# GLC 300 4MATIC
# GLC 300 4MATIC COUPE
# GLE 400 4MATIC
# GLE 550 4MATIC
# GLS 450 4MATIC
# GLS 550 4MATIC
# MAYBACH S 650
# S 450 4MATIC SWB
# S 560 CABRIOLET
# S 560 4MATIC
# S 560 4MATIC SWB
# S 560 4MATIC COUPE
# COOPER 3 DOOR
# COOPER 3 DOOR
# COOPER 5 DOOR
# COOPER 5 DOOR
# COOPER CLUBMAN ALL4
# COOPER CLUBMAN ALL4
# COOPER COUNTRYMAN ALL4
# COOPER COUNTRYMAN ALL4
# COOPER S 3 DOOR
# COOPER S 3 DOOR
# COOPER S 5 DOOR
# COOPER S 5 DOOR
# COOPER S CLUBMAN ALL4
# COOPER S CLUBMAN ALL4
# COOPER S CONVERTIBLE
# COOPER S CONVERTIBLE
# COOPER S COUNTRYMAN ALL4
# COOPER S COUNTRYMAN ALL4
# JOHN COOPER WORKS
# JOHN COOPER WORKS
# JOHN COOPER WORKS CLUBMAN ALL4
# JOHN COOPER WORKS CLUBMAN ALL4
# JOHN COOPER WORKS CONVERTIBLE
# JOHN COOPER WORKS CONVERTIBLE
# JOHN COOPER WORKS COUNTRYMAN ALL4
# JOHN COOPER WORKS COUNTRYMAN ALL4
# ECLIPSE CROSS 4WD
# NV200 CARGO VAN
# PATHFINDER 4WD PLATINUM
# TITAN 4WD PRO-4X
# 911 CARRERA CABRIOLET
# 911 CARRERA CABRIOLET
# 911 CARRERA GTS
# 911 CARRERA GTS
# 911 CARRERA GTS CABRIOLET
# 911 CARRERA GTS CABRIOLET
# 911 CARRERA S
# 911 CARRERA S
# 911 CARRERA S CABRIOLET
# 911 CARRERA S CABRIOLET
# 911 CARRERA 4
# 911 CARRERA 4
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4 CABRIOLET
# 911 CARRERA 4 GTS
# 911 CARRERA 4 GTS
# 911 CARRERA 4 GTS CABRIOLET
# 911 CARRERA 4 GTS CABRIOLET
# 911 CARRERA 4S
# 911 CARRERA 4S
# 911 CARRERA 4S CABRIOLET
# 911 CARRERA 4S CABRIOLET
# 911 TARGA 4
# 911 TARGA 4
# 911 TARGA 4 GTS
# 911 TARGA 4 GTS
# 911 TARGA 4S
# 911 TARGA 4S
# 911 TURBO CABRIOLET
# 911 TURBO S
# 911 TURBO S CABRIOLET
# 911 TURBO S EXCLUSIVE
# CAYENNE TURBO S
# MACAN TURBO KIT
# PANAMERA 4 EXECUTIVE
# PANAMERA 4 ST
# PANAMERA 4S EXECUTIVE
# PANAMERA 4S ST
# PANAMERA TURBO EXECUTIVE
# PANAMERA TURBO ST
# 1500 4X4 FFV
# 1500 4X4 FFV
# 1500 4X4 ECODIESEL
# IMPREZA 4-DOOR AWD
# IMPREZA 4-DOOR AWD
# IMPREZA 5-DOOR AWD
# IMPREZA 5-DOOR AWD
# WRX STI AWD
# WRX STI AWD TYPE RA
# 4RUNNER 4WD (Part-Time 4WD)
# CAMRY HYBRID LE
# CAMRY HYBRID XLE/SE
# COROLLA LE ECO (1-mode)
# COROLLA LE ECO (2-mode)
# HIGHLANDER AWD (Start/Stop System)
# HIGHLANDER AWD LE
# HIGHLANDER HYBRID AWD
# RAV4 LIMITED/SE AWD
# RAV4 HYBRID AWD
# TACOMA 4WD D-CAB OFF-ROAD
# BEETLE DUNE CONVERTIBLE
# GOLF SPORTWAGEN 4MOTION
# GOLF SPORTWAGEN 4MOTION
# S60 T5 AWD
# S60 T6 AWD
# S60 CC T5 AWD
# S90 T5 AWD
# S90 T6 AWD
# V60 T5 AWD
# V60 T6 AWD
# V60 CC T5 AWD
# V90 T6 AWD
# V90 CC T5 AWD
# V90 CC T6 AWD
# XC60 T5 AWD
# XC60 T6 AWD
# XC90 T5 AWD
# XC90 T6 AWD
# MDX SH-AWD A-SPEC
# MDX Hybrid AWD
# RDX AWD A-SPEC
# TLX SH-AWD A-SPEC
# Stelvio AWD Quadrifoglio
# A3 Cabriolet quattro
# A4 allroad quattro
# A5 Cabriolet quattro
# A5 Sportback quattro
# RS 5 Coupe
# RS 5 Sportback
# TT Coupe quattro
# TT Roadster quattro
# TT RS Coupe
# 230i xDrive Cabriolet
# 230i xDrive Coupe
# 330i xDrive Gran Turismo
# 330i xDrive Touring
# 430i xDrive Cabriolet
# 430i xDrive Coupe
# 430i xDrive Gran Coupe
# 440i xDrive Cabriolet
# 440i xDrive Coupe
# 440i xDrive Coupe
# 440i xDrive Gran Coupe
# 640i xDrive Gran Coupe
# 640i xDrive Gran Turismo
# 650i xDrive Gran Coupe
# Alpina B6 xDrive Gran Coupe
# Alpina B7 xDrive
# M240i Coupe M Performance
# M240i Coupe M Performance
# M240i xDrive Cabriolet
# M240i xDrive Coupe
# M240i xDrive Coupe M Performance
# M4 Cabriolet Competition
# M4 Cabriolet Competition
# M4 Coupe Competition
# M4 Coupe Competition
# M6 Gran Coupe
# M850i xDrive Cabriolet
# M850i xDrive Coupe
# Encore (SIDI with Stop/Start)
# Encore AWD (SIDI with Stop/Start)
# XTS Vsport AWD
# Colorado ZR2 4WD
# Colorado ZR2 4WD
# Cruze Hatchback Premier
# Cruze Hatchback Diesel
# Silverado 4WD Trail Boss
# Silverado 4WD FFV
# Silverado 4WD FFV
# Silverado 4WD Trail Boss
# Silverado 4WD Trail Boss
# Silverado LD 4WD
# Suburban 4WD FFV
# Suburban 4WD FFV
# Tahoe 4WD FFV
# Tahoe 4WD FFV
# 300 AWD FFV
# 300 AWD FFV
# Challenger GT AWD
# Challenger SRT Hellcat
# Challenger SRT Hellcat
# Challenger SRT Hellcat Redeye
# Charger AWD FFV
# Charger AWD FFV
# Charger AWD (MDS)
# Charger SRT Hellcat
# Durango AWD SRT
# Grand Caravan FFV
# Grand Caravan FFV
# Expedition MAX 4X4
# Explorer FFV AWD
# Explorer FFV AWD
# F-150 (LT Tire Pkg)
# F-150 (Payload Pkg)
# F-150 (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 (LT Tire Pkg)
# F-150 (Payload Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 FFV (Payload Pkg)
# F-150 FFV (Payload Pkg)
# F-150 4X4 (LT Tire Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 4X4 (LT Tire Pkg)
# F-150 4X4 XL/XLT
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 4X4 (LT Tire Pkg)
# F-150 4X4 (Payload Pkg)
# F-150 4X4 Limited
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (LT Tire Pkg)
# F-150 FFV 4X4 (Payload Pkg)
# F-150 FFV 4X4 (Payload Pkg)
# F-150 Raptor 4X4
# Flex AWD GTDI
# Mustang (Performance Pkg)
# Mustang (Performance Pkg)
# Shelby GT350 Mustang
# Taurus FFV AWD
# Taurus FFV AWD
# Transit Connect Van
# Transit Connect Van FFV
# Transit Connect Van FFV
# Transit Connect Van
# Transit Connect Wagon LWB
# Transit Connect Wagon LWB FFV
# Transit Connect Wagon LWB FFV
# Transit Connect Wagon LWB
# Sierra 4WD FFV
# Sierra 4WD FFV
# Sierra 4WD AT4
# Sierra 4WD AT4
# Sierra LTD 4WD
# Yukon 4WD FFV
# Yukon 4WD FFV
# Yukon XL FFV
# Yukon XL FFV
# Yukon XL 4WD
# Yukon XL 4WD FFV
# Yukon XL 4WD FFV
# Yukon XL 4WD
# Civic Coupe Si
# Civic Hatchback Sport
# Civic Hatchback Sport
# Civic Sedan Si
# Civic Type R
# Santa Fe AWD
# Santa Fe AWD
# Santa Fe XL
# Santa Fe XL AWD
# Santa Fe XL Ultimate AWD
# Sonata Hybrid SE
# Q50 AWD Red Sport
# Q60 AWD Red Sport
# F-TYPE Convertible R-Dynamic
# F-TYPE Convertible R-Dynamic
# F-TYPE Convertible R-Dynamic AWD
# F-TYPE Coupe R-Dynamic
# F-TYPE Coupe R-Dynamic
# F-TYPE Coupe R-Dynamic AWD
# F-TYPE R AWD Convertible
# F-TYPE R AWD Coupe
# XE 20d AWD
# XE 25t AWD
# XE 35t AWD
# XF 20d AWD
# XF 25t AWD
# XF 35t AWD
# XJ R-Sport AWD
# XJL Portfolio AWD
# Cherokee 4X4 Active Drive I
# Cherokee 4X4 Active Drive I
# Cherokee 4X4 Active Drive I
# Cherokee 4X4 Active Drive II
# Cherokee 4X4 Active Drive II
# Cherokee 4X4 Active Drive Lock
# Cherokee 4X4 Active Drive Lock
# Grand Cherokee 4X4
# Grand Cherokee 4X4
# Grand Cherokee 4X4 EcoDiesel
# Grand Cherokee 4X4 SRT
# Grand Cherokee 4X4 Trackhawk
# Renegade 4X4 Trailhawk
# Wrangler JL 4X4
# Wrangler JL 4X4
# Wrangler JL 4X4
# Wrangler JL Unlimited 4X4
# Wrangler JL Unlimited 4X4
# Wrangler JL Unlimited 4X4
# Huracan Coupe AWD
# Huracan Spyder AWD
# Huracan Performante Coupe
# Huracan Performante Spyder
# Discovery TD6 Diesel
# Range Rover 3.0
# Range Rover TD6 Diesel
# Range Rover 5.0 Supercharged
# Range Rover SVAutobiography LWB
# Range Rover Sport 3.0
# Range Rover Sport TD6 Diesel
# Range Rover Sport Supercharged
# Range Rover Evoque
# Range Rover Evoque Convertible
# Range Rover Velar D180
# Range Rover Velar P300
# Range Rover Velar P380
# ES 350 F SPORT
# GS 350 AWD
# IS 300 AWD
# IS 350 AWD
# LS 500 AWD
# LS 500h AWD
# NX 300 AWD
# NX 300 AWD F SPORT
# NX 300h AWD
# RC 300 AWD
# RC 350 AWD
# RX 350 AWD
# RX 350 L AWD
# RX 450h AWD
# RX 450h L AWD
# UX 250h AWD
# MKC AWD (Start/Stop)
# MKT Livery AWD
# CX-5 (Cylinder Deactivation)
# CX-5 4WD (Cylinder Deactivation)
# CX-5 Turbo 4WD
# CX-5 Diesel 4WD
# Mazda3 4-Door (SIL)
# Mazda3 4-Door (Cylinder Deactivation)
# Mazda3 4-Door 4WD
# Mazda3 5-Door (SIL)
# Mazda3 5-Door 4WD
# A 220 4MATIC
# A 250 4MATIC
# AMG C 43 4MATIC
# AMG C 43 4MATIC Cabriolet
# AMG C 43 4MATIC Coupe
# AMG C 43 4MATIC Wagon
# AMG C 63
# AMG C 63 S
# AMG C 63 S Cabriolet
# AMG C 63 S Coupe
# AMG CLA 45 4MATIC
# AMG CLS 53 4MATIC+
# AMG E 53 4MATIC+
# AMG E 53 4MATIC+ Cabriolet
# AMG E 53 4MATIC+ Coupe
# AMG E 53 4MATIC+ Wagon
# AMG E 63 S 4MATIC+
# AMG E 63 S 4MATIC+ Wagon
# AMG G 63
# AMG GLA 45 4MATIC
# AMG GLC 43 4MATIC
# AMG GLC 43 4MATIC Coupe
# AMG GLC 63 S 4MATIC+
# AMG GLC 63 S 4MATIC+ Coupe
# AMG GLE 43 4MATIC
# AMG GLE 43 4MATIC Coupe
# AMG GLE 63 S 4MATIC
# AMG GLE 63 S 4MATIC Coupe
# AMG GLS 63 4MATIC
# AMG GT 53 4MATIC+ Coupe
# AMG GT 63 4MATIC+ Coupe
# AMG GT 63 S 4MATIC+ Coupe
# AMG GT C Coupe
# AMG GT C Roadster
# AMG GT R Coupe
# AMG S 63 4MATIC+
# AMG S 63 4MATIC+ Cabriolet
# AMG S 63 4MATIC+ Coupe
# AMG S 65
# AMG S 65 Cabriolet
# AMG S 65 Coupe
# AMG SL 63
# AMG SLC 43
# B 250 4MATIC
# C 300 4MATIC
# C 300 4MATIC Cabriolet
# C 300 4MATIC Coupe
# C 300 4MATIC Wagon
# CLA 250 4MATIC
# CLS 450 4MATIC
# E 300 4MATIC
# E 450 4MATIC
# E 450 4MATIC Cabriolet
# E 450 4MATIC Coupe
# E 450 4MATIC Wagon
# GLA 250 4MATIC
# GLC 300 4MATIC
# GLC 300 4MATIC Coupe
# GLE 400 4MATIC
# GLS 450 4MATIC
# GLS 550 4MATIC
# Maybach S 560 4MATIC
# Maybach S 650
# Metris Cargo LWB
# S 450 4MATIC SWB
# S 560 Cabriolet
# S 560 4MATIC
# S 560 4MATIC SWB
# Cooper 3 Door
# Cooper 3 Door
# Cooper 5 Door
# Cooper 5 Door
# Cooper Clubman ALL4
# Cooper Clubman ALL4
# Cooper Countryman ALL4
# Cooper Countryman ALL4
# Cooper S 3 Door
# Cooper S 3 Door
# Cooper S 5 Door
# Cooper S 5 Door
# Cooper S Clubman ALL4
# Cooper S Clubman ALL4
# Cooper S Convertible
# Cooper S Convertible
# Cooper S Countryman ALL4
# Cooper S Countryman ALL4
# John Cooper Works 3 Door
# John Cooper Works 3 Door
# John Cooper Works Clubman ALL4
# John Cooper Works Clubman ALL4
# John Cooper Works Convertible
# John Cooper Works Convertible
# John Cooper Works Countryman ALL4
# John Cooper Works Countryman ALL4
# Eclipse Cross 4WD
# Altima AWD SR/Platinum
# NV200 Cargo Van
# Pathfinder 4WD Platinum
# Titan 4WD Pro-4X
# 911 Carrera Cabriolet
# 911 Carrera Cabriolet
# 911 Carrera GTS
# 911 Carrera GTS
# 911 Carrera GTS Cabriolet
# 911 Carrera GTS Cabriolet
# 911 Carrera S
# 911 Carrera S
# 911 Carrera S Cabriolet
# 911 Carrera S Cabriolet
# 911 Carrera T
# 911 Carrera T
# 911 Carrera 4
# 911 Carrera 4
# 911 Carrera 4 Cabriolet
# 911 Carrera 4 Cabriolet
# 911 Carrera 4 GTS
# 911 Carrera 4 GTS
# 911 Carrera 4 GTS Cabriolet
# 911 Carrera 4 GTS Cabriolet
# 911 Carrera 4S
# 911 Carrera 4S
# 911 Carrera 4S Cabriolet
# 911 Carrera 4S Cabriolet
# 911 GT2 RS
# 911 GT3 RS
# 911 GT3 Touring
# 911 Targa 4
# 911 Targa 4
# 911 Targa 4 GTS
# 911 Targa 4 GTS
# 911 Targa 4S
# 911 Targa 4S
# 911 Turbo Cabriolet
# 911 Turbo S
# 911 Turbo S Cabriolet
# 911 Turbo S Exclusive Cabriolet
# Panamera 4 Executive
# Panamera 4 ST
# Panamera 4S Executive
# Panamera 4S ST
# Panamera GTS ST
# Panamera Turbo Executive
# Panamera Turbo ST
# 1500 HFE eTorque
# 1500 4X4 eTorque
# 1500 4X4 eTorque
# 1500 Classic EcoDiesel
# 1500 Classic FFV
# 1500 Classic FFV
# 1500 Classic 4X4 EcoDiesel
# 1500 Classic 4X4 FFV
# 1500 Classic 4X4 FFV
# 1500 Classic 4X4
# 1500 Classic 4X4
# Impreza 4-Door AWD
# Impreza 4-Door AWD
# Impreza 5-Door AWD
# Impreza 5-Door AWD
# WRX STI AWD
# 4Runner 4WD (Part-Time 4WD)
# Camry Hybrid LE
# Camry Hybrid XLE/SE
# Corolla LE Eco
# Highlander AWD (Start/Stop System)
# Highlander AWD LE
# Highlander Hybrid AWD
# RAV4 Hybrid AWD
# Tacoma 4WD D-Cab Off-Road
# Beetle Dune Convertible
# Golf SportWagen 4MOTION
# Golf SportWagen 4MOTION
# S60 T6 AWD
# S90 T5 AWD
# S90 T6 AWD
# V60 T6 AWD
# V60 CC T5 AWD
# V90 T6 AWD
# V90 CC T6 AWD
# XC40 T5 AWD
# XC60 T5 AWD
# XC60 T6 AWD
# XC90 T5 AWD
# XC90 T6 AWD
# MDX SH-AWD A-SPEC
# MDX Hybrid AWD
# RDX AWD A-SPEC
# TLX SH-AWD A-SPEC/Limited Edition
# Stelvio AWD Quadrifoglio
# A3 Cabriolet quattro
# A4 allroad quattro
# A5 Cabriolet quattro
# A5 Sportback quattro
# TT Coupe quattro
# TT Roadster quattro
# Continental GT Convertible
# Continental GT Convertible
# 230i xDrive Cabriolet
# 230i xDrive Coupe
# 330i xDrive Sedan
# 430i xDrive Cabriolet
# 430i xDrive Coupe
# 430i xDrive Gran Coupe
# 440i xDrive Cabriolet
# 440i xDrive Coupe
# 440i xDrive Coupe
# 440i xDrive Gran Coupe
# 530i xDrive Sedan
# 540i xDrive Sedan
# 750i xDrive Sedan
# 750Li xDrive Sedan
# Alpina B7 xDrive
# M240i xDrive Cabriolet
# M240i Coupe M Performance
# M240i Coupe M Performance
# M240i xDrive Coupe
# M240i xDrive Coupe M Performance
# M340i xDrive Sedan
# M4 Cabriolet Competition
# M4 Cabriolet Competition
# M4 Coupe Competition
# M4 Coupe Competition
# M550i xDrive Sedan
# M760i xDrive Sedan
# M8 Cabriolet Competition
# M8 Coupe Competition
# M8 Gran Coupe
# M8 Gran Coupe Competition
# M850i xDrive Cabriolet
# M850i xDrive Coupe
# M850i xDrive Gran Coupe
# X3 M Competition
# X4 M Competition
# Encore GX AWD
# Colorado ZR2 4WD
# Colorado ZR2 4WD
# Silverado WT 4WD
# Silverado 4WD Custom Trail Boss
# Silverado 4WD FFV
# Silverado 4WD FFV
# Silverado 4WD Custom Trail Boss
# Silverado 4WD LT Trail Boss
# Silverado 4WD Custom Trail Boss
# Silverado 4WD LT Trail Boss
# Suburban 4WD FFV
# Suburban 4WD FFV
# Tahoe 4WD FFV
# Tahoe 4WD FFV
# Challenger Widebody (MDS)
# Challenger Widebody (MDS)
# Challenger SRT Hellcat
# Challenger SRT Hellcat
# Challenger SRT Hellcat Widebody
# Challenger SRT Hellcat Widebody
# Charger Widebody (MDS)
# Charger SRT Hellcat Widebody
# Durango AWD SRT
# Escape Hybrid AWD
# Expedition MAX 4X4
# Explorer Hybrid AWD
# F-150 (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 FFV (LT Tire Pkg)
# F-150 FFV (Payload Pkg)
# F-150 FFV (Payload Pkg)
# F-150 4X4 XL/XLT
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 4X4 Limited
# F-150 FFV 4X4
# F-150 FFV 4X4
# F-150 Raptor 4X4
# Mustang (Performance Pkg)
# Mustang (Performance Pkg)
# Mustang Convertible (Performance Pkg)
# Mustang Convertible (Performance Pkg)
# Shelby GT350 Mustang
# Shelby GT500 Mustang
# T-150 Wagon FFV
# T-150 Wagon FFV
# T-150 Wagon FFV 4WD
# T-150 Wagon FFV 4WD
# Transit Connect Van FFV
# Transit Connect Van FFV
# Transit Connect Van LWB
# Transit Connect Van LWB
# Transit Connect Wagon LWB
# Transit Connect Wagon LWB FFV
# Transit Connect Wagon LWB FFV
# Transit Connect Wagon LWB
# Sierra WT 4WD
# Sierra 4WD AT4
# Sierra 4WD FFV
# Sierra 4WD FFV
# Sierra 4WD AT4
# Sierra 4WD AT4
# Sierra 4WD AT4
# Sierra 4WD AT4
# Yukon 4WD FFV
# Yukon 4WD FFV
# Yukon XL FFV
# Yukon XL FFV
# Yukon XL 4WD
# Yukon XL 4WD FFV
# Yukon XL 4WD FFV
# Yukon XL 4WD
# Civic Coupe Si
# Civic Hatchback Sport
# Civic Hatchback Sport
# Civic Sedan Si
# Civic Type R
# Santa Fe AWD
# Santa Fe AWD
# Q50 AWD Red Sport
# Q60 AWD Red Sport
# F-TYPE P300 Convertible
# F-TYPE Convertible R-Dynamic
# F-TYPE Convertible R-Dynamic AWD
# F-TYPE R AWD Convertible
# F-TYPE SVR AWD Convertible
# F-TYPE P300 Coupe
# F-TYPE Coupe R-Dynamic
# F-TYPE Coupe R-Dynamic AWD
# F-TYPE R AWD Coupe
# F-TYPE SVR AWD Coupe
# XE P250 AWD
# XE P300 AWD
# XF 25t AWD
# XF 30t AWD
# XF S AWD
# Cherokee 4X4 Active Drive I
# Cherokee 4X4 Active Drive I
# Cherokee 4X4 Active Drive I
# Cherokee 4X4 Active Drive II
# Cherokee 4X4 Active Drive II
# Cherokee 4X4 Active Drive Lock
# Cherokee 4X4 Active Drive Lock
# Grand Cherokee 4X4
# Grand Cherokee 4X4
# Grand Cherokee 4X4 Trackhawk
# Grand Cherokee 4X4 SRT
# Renegade 4X4 Trailhawk
# Wrangler 4X4 eTorque
# Wrangler Unlimited 4X4
# Wrangler Unlimited 4X4 eTorque
# Wrangler Unlimited 4X4 EcoDiesel
# Wrangler Unlimited 4X4
# Wrangler Unlimited 4X4 eTorque
# Wrangler Unlimited 4X4
# Huracan Coupe AWD
# Huracan Spyder AWD
# Discovery TD6 Diesel
# Discovery Sport P250
# Discovery Sport P290
# Range Rover 3.0
# Range Rover TD6 Diesel
# Range Rover 5.0 Supercharged
# Range Rover 5.0 Supercharged LWB
# Range Rover SVAutobiography Dynamic
# Range Rover SVAutobiography LWB
# Range Rover Sport 3.0
# Range Rover Sport TD6 Diesel
# Range Rover Sport Supercharged
# Range Rover Sport SVR
# Range Rover Evoque P250
# Range Rover Evoque P300
# Range Rover Velar P250
# Range Rover Velar P300
# Range Rover Velar P340
# Range Rover Velar P380
# Range Rover Velar SVAutobiography Dynamic
# ES 350 F SPORT
# GS 350 AWD
# IS 300 AWD
# IS 350 AWD
# LS 500 AWD
# LS 500h AWD
# NX 300 AWD
# NX 300 AWD F SPORT
# NX 300h AWD
# RC 300 AWD
# RC 350 AWD
# RX 350 AWD
# RX 350 L AWD
# RX 450h AWD
# RX 450h L AWD
# UX 250h AWD
# Ghibli S Q4
# Quattroporte S Q4
# CX-30 4WD (Cylinder Deactivation)
# CX-5 (Cylinder Deactivation)
# CX-5 4WD (Cylinder Deactivation)
# CX-5 Turbo 4WD
# Mazda3 4-Door (SIL)
# Mazda3 4-Door (Cylinder Deactivation)
# Mazda3 4-Door 4WD
# Mazda3 5-Door (SIL)
# Mazda3 5-Door (SIL)
# Mazda3 5-Door 4WD
# AMG C 43 4MATIC
# AMG C 43 4MATIC Cabriolet
# AMG C 43 4MATIC Coupe
# AMG C 43 4MATIC Wagon
# AMG C 63
# AMG C 63 S
# AMG C 63 S Cabriolet
# AMG C 63 S Coupe
# AMG CLS 53 4MATIC+
# AMG E 53 4MATIC+
# AMG E 53 4MATIC+ Cabriolet
# AMG E 53 4MATIC+ Coupe
# AMG E 63 S 4MATIC+
# AMG E 63 S 4MATIC+ Wagon
# AMG G 63
# AMG GLC 63 S 4MATIC+
# AMG GLC 63 S 4MATIC+ Coupe
# AMG GT R Coupe
# AMG S 63 4MATIC+
# AMG S 63 4MATIC+ Cabriolet
# AMG S 63 4MATIC+ Coupe
# AMG S 65
# C 300 4MATIC
# C 300 4MATIC Cabriolet
# C 300 4MATIC Coupe
# C 300 4MATIC Wagon
# CLS 450 4MATIC
# E 450 4MATIC Cabriolet
# E 450 4MATIC Coupe
# Maybach S 560 4MATIC
# Maybach S 650
# S 450 4MATIC SWB
# S 560 4MATIC
# S 560 4MATIC SWB
# Cooper 3 Door
# Cooper 5 Door
# Cooper Clubman ALL4
# Cooper Countryman ALL4
# Cooper S 3 Door
# Cooper S 5 Door
# Cooper S Clubman ALL4
# Cooper S Convertible
# Cooper S Countryman ALL4
# John Cooper Works 3 Door
# John Cooper Works Clubman ALL4
# John Cooper Works Convertible
# John Cooper Works Countryman ALL4
# Eclipse Cross 4WD
# Altima AWD SR/Platinum
# NV200 Cargo Van
# Pathfinder 4WD Platinum
# Titan 4WD Pro-4X
# 911 Carrera S
# 911 Carrera S Cabriolet
# 911 Carrera 4S
# 911 Carrera 4S Cabriolet
# Panamera 4 Executive
# Panamera 4 ST
# Panamera 4S Executive
# Panamera 4S ST
# Panamera GTS ST
# Panamera Turbo Executive
# Panamera Turbo ST
# 1500 HFE eTorque
# 1500 4X4 EcoDiesel
# 1500 4X4 eTorque
# 1500 4X4 eTorque
# 1500 Classic 4X4
# 1500 Classic 4X4
# Cullinan Black Badge
# Impreza 4-Door AWD
# Impreza 4-Door AWD
# Impreza 5-Door AWD
# Impreza 5-Door AWD
# WRX STI AWD
# 4Runner 4WD (Part-Time 4WD)
# Camry AWD LE/SE
# Camry AWD XLE/XSE
# Camry Hybrid LE
# Camry Hybrid XLE/SE
# Highlander Hybrid AWD
# Highlander Hybrid AWD Limited/Platinum
# RAV4 AWD TRD Off-Road
# RAV4 Hybrid AWD
# Tacoma 4WD D-Cab TRD Off-Road/Pro
# Atlas Cross Sport 4MOTION
# S60 T6 AWD
# S90 T6 AWD
# V60 T6 AWD
# V60 CC T5 AWD
# XC40 T4 AWD
# XC40 T5 AWD
# XC60 T5 AWD
# XC60 T6 AWD
# XC90 T5 AWD
# XC90 T6 AWD

# %% [markdown]
# All in all I think that the model names should be tackled at feature engineering level. For now we will take the classic method of taking the **average** fuel consumption ane emissions. This is done to keep a single row of data per model.

# %% [markdown]
# ### Averaging the consumption and emissions
#
# Running the code below will create one row of data per model with a unique set of engine and tranmission option. ***reset_index*** function returns the groupby into a dataframe.

# %%
clean_df = df.groupby(['make', 'model', 'engine_size', 'transmission']).mean().reset_index()
clean_df.head()
# Out:
#     make       model  engine_size transmission  cylinders  \
# 0  ACURA         ILX          2.0          AS5        4.0
# 1  ACURA         ILX          2.4          AM8        4.0
# 2  ACURA         ILX          2.4           M6        4.0
# 3  ACURA  ILX HYBRID          1.5          CVT        4.0
# 4  ACURA     MDX 4WD          3.5          AS6        6.0
#
#    fuel_consumption_city  fuel_consumption_hwy  fuel_consumption_comb  \
# 0                   9.80                  6.70                   8.40
# 1                   9.58                  6.84                   8.34
# 2                  11.00                  7.55                   9.45
# 3                   6.00                  5.95                   6.00
# 4                  12.70                  9.10                  11.10
#
#    emissions
# 0      193.5
# 1      194.2
# 2      217.5
# 3      138.0
# 4      255.0

# %% [markdown]
# ## Saving the DataFrame

# %%
clean_df.to_csv('..\data\Emissions_Clean.csv')
